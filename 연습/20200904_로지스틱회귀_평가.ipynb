# %%
# 모듈 가져오기
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
# 데이터 불러오기
credit_data = pd.read_csv('./Data/german_credit_new.csv')

# %% [markdown]
# ## 데이터 확인 및 탐색하기

# %%
# 데이터 shape 확인하기
credit_data.shape
# Out:
# (1000, 21)

# %%
# 데이터 컬럼 및 타입 확인하기
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Status of existing checking account                       1000 non-null   object
#  1   Duration in month                                         1000 non-null   int64
#  2   Credit history                                            1000 non-null   object
#  3   Purpose                                                   1000 non-null   object
#  4   Credit amount                                             1000 non-null   int64
#  5   Savings account/bonds                                     1000 non-null   object
#  6   Present employment since                                  1000 non-null   object
#  7   Installment rate in percentage of disposable income       1000 non-null   int64
#  8   Personal status and sex                                   1000 non-null   object
#  9   Other debtors / guarantors                                1000 non-null   object
#  10  Present residence since                                   1000 non-null   int64
#  11  Property                                                  1000 non-null   object
#  12  Age in years                                              1000 non-null   int64
#  13  Other installment plans                                   1000 non-null   object
#  14  Housing                                                   1000 non-null   object
#  15  Number of existing credits at this bank                   1000 non-null   int64
#  16  Job                                                       1000 non-null   object
#  17  Number of people being liable to provide maintenance for  1000 non-null   int64
#  18  Telephone                                                 1000 non-null   object
#  19  foreign worker                                            1000 non-null   object
#  20  class                                                     1000 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 164.2+ KB

# %%
# object와 ,int 타입 데이터가 존재
# 컬럼명에 공백이 들어가 있다. 공백 -> "_"
credit_data.columns = credit_data.columns.str.replace(' ', '_')
# 다른방법으로는
# credit_data.rename(columns = lambda x : x.replace(' ', '_'))

# %%
# 종속변수 확인 =>: class
credit_data['class'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
# 종속변수가 1, 2로 되어있다. -> 0, 1로 변환시키자
credit_data['class'] = credit_data['class'] - 1

# %%
# 종속변수 확인
credit_data['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# 데이터 확인 - head()
credit_data.head()
# Out:
#   Status_of_existing_checking_account  Duration_in_month Credit_history  \
# 0                                 A11                  6            A34
# 1                                 A12                 48            A32
# 2                                 A14                 12            A34
# 3                                 A11                 42            A32
# 4                                 A11                 24            A33
#
#   Purpose  Credit_amount Savings_account/bonds Present_employment_since  \
# 0     A43           1169                   A65                      A75
# 1     A43           5951                   A61                      A73
# 2     A46           2096                   A61                      A74
# 3     A42           7882                   A61                      A74
# 4     A40           4870                   A61                      A73
#
#    Installment_rate_in_percentage_of_disposable_income  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#   Personal_status_and_sex Other_debtors_/_guarantors  ...  Property  \
# 0                     A93                       A101  ...      A121
# 1                     A92                       A101  ...      A121
# 2                     A93                       A101  ...      A121
# 3                     A93                       A103  ...      A122
# 4                     A93                       A101  ...      A124
#
#   Age_in_years  Other_installment_plans Housing  \
# 0           67                     A143    A152
# 1           22                     A143    A152
# 2           49                     A143    A152
# 3           45                     A143    A153
# 4           53                     A143    A153
#
#   Number_of_existing_credits_at_this_bank   Job  \
# 0                                       2  A173
# 1                                       1  A173
# 2                                       1  A172
# 3                                       1  A173
# 4                                       2  A173
#
#   Number_of_people_being_liable_to_provide_maintenance_for  Telephone  \
# 0                                                  1             A192
# 1                                                  1             A191
# 2                                                  2             A191
# 3                                                  2             A191
# 4                                                  2             A191
#
#   foreign_worker class
# 0           A201     0
# 1           A201     1
# 2           A201     0
# 3           A201     0
# 4           A201     1
#
# [5 rows x 21 columns]

# %%
# 신용 데이터
# 종속변수
# 0 : 신용양호
# 1 : 신용불량자

# %% [markdown]
# ## 독립변수에 관한 각 변수의 예측 능력을 알아보기 위해 정보가치를 계산해본다.
# <h2> 정보가치 = $ ln(\frac{good}{bad})(good - bad)  $ </h2>
# <h2> 증거 가중값 = $ ln(\frac{good}{bad})$</h2>

# %%
# 임의의 명목형 변수에 대해서 groupby -> class에 대해서만 count, sum
# 왜냐하면, class는 0과 1의 이진화변수이기 때문에 sum의 경우 1인 경우의 숫자를 알 수 있다.
dataf = credit_data.groupby(['Credit_history'])['class'].agg(['count', 'sum'])
dataf.columns = ['Total', 'bad'] # class가 1인 경우가 신용 불량자 : bad
dataf['good'] = dataf["Total"] - dataf['bad']
dataf['bad_per'] = dataf['bad'] / dataf['bad'].sum()
dataf['good_per'] = dataf['good'] / dataf['good'].sum()
dataf['I_V'] = np.log(dataf['good_per']/dataf['bad_per']) * (dataf['good_per'] - dataf['bad_per'])

# %%
# 데이터 확인
dataf
# Out:
#                 Total  bad  good   bad_per  good_per       I_V
# Credit_history
# A30                40   25    15  0.083333  0.021429  0.084074
# A31                49   28    21  0.093333  0.030000  0.071882
# A32               530  169   361  0.563333  0.515714  0.004206
# A33                88   28    60  0.093333  0.085714  0.000649
# A34               293   50   243  0.166667  0.347143  0.132423

# %%
# 임의의 연속형 변수에 대해서는 범주화가 필요하다. => 범주화를 통해서 명목화 시킬 수 있다.
# 로지스틱 회귀는 기본적으로 분류를 위한 모델이기 때문에 범주화가 필수
# 범주화 시, 내림차순으로 정렬하는것이 매우 중요하다.
tmp_df = credit_data[:]
tmp_df['bin_var'] = pd.qcut(credit_data['Duration_in_month'].rank(method = 'first'),10)
dataf = tmp_df.groupby(['bin_var'])['class'].agg(['count', 'sum'])
dataf.columns = ['Total', 'bad'] # class가 1인 경우가 신용 불량자 : bad
dataf['good'] = dataf["Total"] - dataf['bad']
dataf['bad_per'] = dataf['bad'] / dataf['bad'].sum()
dataf['good_per'] = dataf['good'] / dataf['good'].sum()
dataf['I_V'] = np.log(dataf['good_per']/dataf['bad_per']) * (dataf['good_per'] - dataf['bad_per'])
# Out:
# <ipython-input-13-b8fa552e85ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['bin_var'] = pd.qcut(credit_data['Duration_in_month'].rank(method = 'first'),10)

# %%
# 데이터 확인
dataf
# Out:
#                  Total  bad  good   bad_per  good_per       I_V
# bin_var
# (0.999, 100.9]     100   11    89  0.036667  0.127143  0.112502
# (100.9, 200.8]     100   20    80  0.066667  0.114286  0.025667
# (200.8, 300.7]     100   27    73  0.090000  0.104286  0.002105
# (300.7, 400.6]     100   25    75  0.083333  0.107143  0.005984
# (400.6, 500.5]     100   26    74  0.086667  0.105714  0.003784
# (500.5, 600.4]     100   38    62  0.126667  0.088571  0.013629
# (600.4, 700.3]     100   32    68  0.106667  0.097143  0.000891
# (700.3, 800.2]     100   31    69  0.103333  0.098571  0.000225
# (800.2, 900.1]     100   42    58  0.140000  0.082857  0.029973
# (900.1, 1000.0]    100   48    52  0.160000  0.074286  0.065765

# %%
# 모든 독립변수에 대해서 자동화를 위해 함수를 만든다.
def IV_calc(data, var):
    if data[var].dtypes == 'object':
        dataf = credit_data.groupby([var])['class'].agg(['count', 'sum'])
        dataf.columns = ['Total', 'bad'] # class가 1인 경우가 신용 불량자 : bad
        dataf['good'] = dataf["Total"] - dataf['bad']
        dataf['bad_per'] = dataf['bad'] / dataf['bad'].sum()
        dataf['good_per'] = dataf['good'] / dataf['good'].sum()
        dataf['I_V'] = np.log(dataf['good_per']/dataf['bad_per']) * (dataf['good_per'] - dataf['bad_per'])
        
        return dataf
    
    elif data[var].dtypes == 'int64':
        data['bin_var'] = pd.qcut(credit_data[var].rank(method = 'first'),10)
        dataf = data.groupby(['bin_var'])['class'].agg(['count', 'sum'])
        dataf.columns = ['Total', 'bad'] # class가 1인 경우가 신용 불량자 : bad
        dataf['good'] = dataf["Total"] - dataf['bad']
        dataf['bad_per'] = dataf['bad'] / dataf['bad'].sum()
        dataf['good_per'] = dataf['good'] / dataf['good'].sum()
        dataf['I_V'] = np.log(dataf['good_per']/dataf['bad_per']) * (dataf['good_per'] - dataf['bad_per'])

        return dataf

# %%
# credit_data의 컬럼에서 명목형 변수와, 연속형 변수를 분리하자.
discrete_columns = list()
continuous_columns = list()
for i in range(0,len(credit_data.dtypes)):
    if credit_data.dtypes[i] == 'object':
        discrete_columns.append(credit_data.columns[i])
    elif credit_data.dtypes[i]  == 'int64':
        continuous_columns.append(credit_data.columns[i])

# %%
# 컬럼 확인
print(discrete_columns)
print(continuous_columns)
# Out:
# ['Status_of_existing_checking_account', 'Credit_history', 'Purpose', 'Savings_account/bonds', 'Present_employment_since', 'Personal_status_and_sex', 'Other_debtors_/_guarantors', 'Property', 'Other_installment_plans', 'Housing', 'Job', 'Telephone', 'foreign_worker']
# ['Duration_in_month', 'Credit_amount', 'Installment_rate_in_percentage_of_disposable_income', 'Present_residence_since', 'Age_in_years', 'Number_of_existing_credits_at_this_bank', 'Number_of_people_being_liable_to_provide_maintenance_for', 'class']

# %%
# 컬럼 정의
total_columns = discrete_columns + continuous_columns
total_columns
# Out:
# ['Status_of_existing_checking_account',
#  'Credit_history',
#  'Purpose',
#  'Savings_account/bonds',
#  'Present_employment_since',
#  'Personal_status_and_sex',
#  'Other_debtors_/_guarantors',
#  'Property',
#  'Other_installment_plans',
#  'Housing',
#  'Job',
#  'Telephone',
#  'foreign_worker',
#  'Duration_in_month',
#  'Credit_amount',
#  'Installment_rate_in_percentage_of_disposable_income',
#  'Present_residence_since',
#  'Age_in_years',
#  'Number_of_existing_credits_at_this_bank',
#  'Number_of_people_being_liable_to_provide_maintenance_for',
#  'class']

# %%
# (I_V 값, 컬럼명, 데이터 타입) 형태로 데이터를 정제하자
# I_V값을 계산하기 위해 위에서 정의했던 IV_calc함수를 사용
IV_list = list()
for col in total_columns:
    assigned_data = IV_calc(data = credit_data, var = col)
    IV_val = round(assigned_data['I_V'].sum(),3)
    dt_type = credit_data[col].dtypes
    IV_list.append((IV_val, col, dt_type))
# Out:
# C:\Users\bcduc\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# 데이터 확인
IV_list.sort(reverse = True)
IV_list
# Out:
# [(inf, 'class', dtype('int64')),
#  (0.666, 'Status_of_existing_checking_account', dtype('O')),
#  (0.293, 'Credit_history', dtype('O')),
#  (0.261, 'Duration_in_month', dtype('int64')),
#  (0.196, 'Savings_account/bonds', dtype('O')),
#  (0.169, 'Purpose', dtype('O')),
#  (0.113, 'Property', dtype('O')),
#  (0.113, 'Credit_amount', dtype('int64')),
#  (0.103, 'Age_in_years', dtype('int64')),
#  (0.098, 'Number_of_existing_credits_at_this_bank', dtype('int64')),
#  (0.086, 'Present_employment_since', dtype('O')),
#  (0.083, 'Housing', dtype('O')),
#  (0.062,
#   'Installment_rate_in_percentage_of_disposable_income',
#   dtype('int64')),
#  (0.058, 'Other_installment_plans', dtype('O')),
#  (0.049, 'Present_residence_since', dtype('int64')),
#  (0.045, 'Personal_status_and_sex', dtype('O')),
#  (0.044, 'foreign_worker', dtype('O')),
#  (0.034,
#   'Number_of_people_being_liable_to_provide_maintenance_for',
#   dtype('int64')),
#  (0.032, 'Other_debtors_/_guarantors', dtype('O')),
#  (0.009, 'Job', dtype('O')),
#  (0.006, 'Telephone', dtype('O'))]

# %%
# 종속변수 class에 대한 모든 독립변수의 정보가치를 계산했다.
# 이 때, 상위 15개만 선택한다.
IV_list_top15 = IV_list[0:15]
IV_list_top15
# Out:
# [(inf, 'class', dtype('int64')),
#  (0.666, 'Status_of_existing_checking_account', dtype('O')),
#  (0.293, 'Credit_history', dtype('O')),
#  (0.261, 'Duration_in_month', dtype('int64')),
#  (0.196, 'Savings_account/bonds', dtype('O')),
#  (0.169, 'Purpose', dtype('O')),
#  (0.113, 'Property', dtype('O')),
#  (0.113, 'Credit_amount', dtype('int64')),
#  (0.103, 'Age_in_years', dtype('int64')),
#  (0.098, 'Number_of_existing_credits_at_this_bank', dtype('int64')),
#  (0.086, 'Present_employment_since', dtype('O')),
#  (0.083, 'Housing', dtype('O')),
#  (0.062,
#   'Installment_rate_in_percentage_of_disposable_income',
#   dtype('int64')),
#  (0.058, 'Other_installment_plans', dtype('O')),
#  (0.049, 'Present_residence_since', dtype('int64'))]

# %% [markdown]
# ## 명목형 변수 -> 더미변수로 변환이 필요

# %%
# IV_list_top15에서 명목형 변수와 연속형 변수 분리하자
discrete_columns_new = list()
continuous_columns_new = list()
for i in IV_list_top15:
    if i[2] == 'object':
        discrete_columns_new.append(i[1])
    elif i[2] == 'int64':
        continuous_columns_new.append(i[1])

# %%
# 데이터 확인하기
print(discrete_columns_new)
print(continuous_columns_new)
# Out:
# ['Status_of_existing_checking_account', 'Credit_history', 'Savings_account/bonds', 'Purpose', 'Property', 'Present_employment_since', 'Housing', 'Other_installment_plans']
# ['class', 'Duration_in_month', 'Credit_amount', 'Age_in_years', 'Number_of_existing_credits_at_this_bank', 'Installment_rate_in_percentage_of_disposable_income', 'Present_residence_since']

# %%
# 명목형 변수 더미변수로 변환하기
credit_data_new = pd.concat(
    [
        pd.get_dummies(credit_data[discrete_columns_new]),
        credit_data[continuous_columns_new].drop('class', axis= 1),
        credit_data['class']
    ],axis = 1)

# %%
# 데이터 컬럼 확인
credit_data_new.columns
# Out:
# Index(['Status_of_existing_checking_account_A11',
#        'Status_of_existing_checking_account_A12',
#        'Status_of_existing_checking_account_A13',
#        'Status_of_existing_checking_account_A14', 'Credit_history_A30',
#        'Credit_history_A31', 'Credit_history_A32', 'Credit_history_A33',
#        'Credit_history_A34', 'Savings_account/bonds_A61',
#        'Savings_account/bonds_A62', 'Savings_account/bonds_A63',
#        'Savings_account/bonds_A64', 'Savings_account/bonds_A65', 'Purpose_A40',
#        'Purpose_A41', 'Purpose_A410', 'Purpose_A42', 'Purpose_A43',
#        'Purpose_A44', 'Purpose_A45', 'Purpose_A46', 'Purpose_A48',
#        'Purpose_A49', 'Property_A121', 'Property_A122', 'Property_A123',
#        'Property_A124', 'Present_employment_since_A71',
#        'Present_employment_since_A72', 'Present_employment_since_A73',
#        'Present_employment_since_A74', 'Present_employment_since_A75',
#        'Housing_A151', 'Housing_A152', 'Housing_A153',
#        'Other_installment_plans_A141', 'Other_installment_plans_A142',
#        'Other_installment_plans_A143', 'Duration_in_month', 'Credit_amount',
#        'Age_in_years', 'Number_of_existing_credits_at_this_bank',
#        'Installment_rate_in_percentage_of_disposable_income',
#        'Present_residence_since', 'class'],
#       dtype='object')

# %% [markdown]
# ## train 데이터, test 데이터 분할

# %%
# 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(
    credit_data_new.drop(['class'], axis = 1), credit_data_new['class'], train_size = 0.7, random_state = 42)

# %%
# 데이터 shape 확인
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 45), (300, 45), (700,), (300,))

# %%
# 데이터 타입 확인

# %%
type(x_train), type(x_test), type(y_train), type(y_test)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.series.Series,
#  pandas.core.series.Series)

# %%
# 시리즈 -> 데이터 프레임
y_train = y_train.to_frame()
y_test = y_test.to_frame()

# %%
# x_train 확인
x_train
# Out:
#      Status_of_existing_checking_account_A11  \
# 541                                        0
# 440                                        0
# 482                                        1
# 422                                        0
# 778                                        0
# ..                                       ...
# 106                                        0
# 270                                        0
# 860                                        0
# 435                                        0
# 102                                        0
#
#      Status_of_existing_checking_account_A12  \
# 541                                        0
# 440                                        0
# 482                                        0
# 422                                        1
# 778                                        0
# ..                                       ...
# 106                                        0
# 270                                        0
# 860                                        0
# 435                                        1
# 102                                        0
#
#      Status_of_existing_checking_account_A13  \
# 541                                        0
# 440                                        0
# 482                                        0
# 422                                        0
# 778                                        0
# ..                                       ...
# 106                                        0
# 270                                        0
# 860                                        0
# 435                                        0
# 102                                        0
#
#      Status_of_existing_checking_account_A14  Credit_history_A30  \
# 541                                        1                   0
# 440                                        1                   0
# 482                                        0                   0
# 422                                        0                   0
# 778                                        1                   0
# ..                                       ...                 ...
# 106                                        1                   0
# 270                                        1                   0
# 860                                        1                   0
# 435                                        0                   0
# 102                                        1                   0
#
#      Credit_history_A31  Credit_history_A32  Credit_history_A33  \
# 541                   0                   0                   1
# 440                   0                   1                   0
# 482                   0                   1                   0
# 422                   0                   0                   0
# 778                   0                   0                   0
# ..                  ...                 ...                 ...
# 106                   1                   0                   0
# 270                   0                   1                   0
# 860                   0                   0                   0
# 435                   0                   1                   0
# 102                   0                   0                   1
#
#      Credit_history_A34  Savings_account/bonds_A61  ...  Housing_A153  \
# 541                   0                          1  ...             1
# 440                   0                          1  ...             0
# 482                   0                          0  ...             0
# 422                   1                          1  ...             0
# 778                   1                          0  ...             0
# ..                  ...                        ...  ...           ...
# 106                   0                          1  ...             0
# 270                   0                          0  ...             0
# 860                   1                          0  ...             0
# 435                   0                          0  ...             0
# 102                   0                          1  ...             0
#
#      Other_installment_plans_A141  Other_installment_plans_A142  \
# 541                             0                             0
# 440                             0                             0
# 482                             0                             0
# 422                             0                             0
# 778                             0                             0
# ..                            ...                           ...
# 106                             1                             0
# 270                             0                             0
# 860                             0                             0
# 435                             0                             0
# 102                             0                             0
#
#      Other_installment_plans_A143  Duration_in_month  Credit_amount  \
# 541                             1                 24           2032
# 440                             1                 12           1884
# 482                             1                 30           3622
# 422                             1                 12            958
# 778                             1                 36           5711
# ..                            ...                ...            ...
# 106                             0                 18           6458
# 270                             1                 18           2662
# 860                             1                 24           5804
# 435                             1                 12           1484
# 102                             1                  6            932
#
#      Age_in_years  Number_of_existing_credits_at_this_bank  \
# 541            60                                        2
# 440            39                                        1
# 482            57                                        2
# 422            47                                        2
# 778            38                                        2
# ..            ...                                      ...
# 106            39                                        2
# 270            32                                        1
# 860            27                                        2
# 435            25                                        1
# 102            24                                        1
#
#      Installment_rate_in_percentage_of_disposable_income  \
# 541                                                  4
# 440                                                  4
# 482                                                  4
# 422                                                  2
# 778                                                  4
# ..                                                 ...
# 106                                                  2
# 270                                                  4
# 860                                                  4
# 435                                                  2
# 102                                                  3
#
#      Present_residence_since
# 541                        4
# 440                        4
# 482                        4
# 422                        3
# 778                        2
# ..                       ...
# 106                        4
# 270                        3
# 860                        2
# 435                        1
# 102                        2
#
# [700 rows x 45 columns]

# %% [markdown]
# ### 더미 변수의 성질을 이용하자.
# ### 독립변수의 값이 N가지이면 N-1가지의 더미변수로 N가지의 종류를 표현할 수 있다.
# ### 즉, 불필요한 더미변수를 삭제

# %% [markdown]
# ## 로지스틱 회귀 모델 생성 및 학습

# %%
import statsmodels.api as sm

# 제거할 컬럼 정의
remove_cols_extra_dummy = [
    'Status_of_existing_checking_account_A11',
    'Credit_history_A30',
    'Savings_account/bonds_A61',
    'Purpose_A40',
    'Property_A121',
    'Present_employment_since_A71',
    'Housing_A151',
    'Other_installment_plans_A141',
    
]
# 실행이 반복될 때마다 가장 무의미한 변수와 다중공선성을 갖는 변수를
# remove_cols_insig 리스트에 추가한다.
remove_cols_insig = list()
remove_cols = list(set(remove_cols_extra_dummy + remove_cols_insig))
logistic_model = sm.Logit(y_train, sm.add_constant(x_train.drop(remove_cols, axis = 1))).fit()
print(logistic_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.462575
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  class   No. Observations:                  700
# Model:                          Logit   Df Residuals:                      662
# Method:                           MLE   Df Model:                           37
# Date:                Fri, 04 Sep 2020   Pseudo R-squ.:                  0.2412
# Time:                        22:09:59   Log-Likelihood:                -323.80
# converged:                       True   LL-Null:                       -426.75
# Covariance Type:            nonrobust   LLR p-value:                 2.594e-25
# =======================================================================================================================
#                                                           coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# const                                                   0.6915      0.990      0.698      0.485      -1.249       2.632
# Status_of_existing_checking_account_A12                -0.2804      0.255     -1.098      0.272      -0.781       0.220
# Status_of_existing_checking_account_A13                -0.9375      0.453     -2.070      0.038      -1.825      -0.050
# Status_of_existing_checking_account_A14                -1.4876      0.271     -5.491      0.000      -2.019      -0.957
# Credit_history_A31                                      0.0618      0.619      0.100      0.921      -1.152       1.276
# Credit_history_A32                                     -0.4092      0.469     -0.872      0.383      -1.329       0.511
# Credit_history_A33                                     -1.0286      0.527     -1.951      0.051      -2.062       0.005
# Credit_history_A34                                     -1.4420      0.482     -2.990      0.003      -2.387      -0.497
# Savings_account/bonds_A62                              -0.2889      0.337     -0.857      0.391      -0.949       0.372
# Savings_account/bonds_A63                              -0.6857      0.478     -1.434      0.152      -1.623       0.252
# Savings_account/bonds_A64                              -0.9898      0.606     -1.633      0.103      -2.178       0.198
# Savings_account/bonds_A65                              -0.6674      0.291     -2.290      0.022      -1.239      -0.096
# Purpose_A41                                            -1.6097      0.422     -3.819      0.000      -2.436      -0.784
# Purpose_A410                                           -1.0750      0.784     -1.371      0.171      -2.612       0.462
# Purpose_A42                                            -1.0289      0.316     -3.252      0.001      -1.649      -0.409
# Purpose_A43                                            -1.0369      0.287     -3.618      0.000      -1.599      -0.475
# Purpose_A44                                            -0.4265      0.761     -0.561      0.575      -1.917       1.064
# Purpose_A45                                            -0.6366      0.631     -1.009      0.313      -1.873       0.600
# Purpose_A46                                             0.1750      0.490      0.357      0.721      -0.785       1.135
# Purpose_A48                                            -1.8128      1.165     -1.556      0.120      -4.096       0.471
# Purpose_A49                                            -0.5128      0.389     -1.319      0.187      -1.275       0.249
# Property_A122                                           0.3954      0.295      1.342      0.180      -0.182       0.973
# Property_A123                                           0.3667      0.269      1.361      0.174      -0.162       0.895
# Property_A124                                           0.7983      0.492      1.624      0.104      -0.165       1.762
# Present_employment_since_A72                            0.1062      0.441      0.241      0.810      -0.757       0.970
# Present_employment_since_A73                           -0.0430      0.410     -0.105      0.917      -0.846       0.760
# Present_employment_since_A74                           -0.4737      0.454     -1.044      0.297      -1.363       0.416
# Present_employment_since_A75                           -0.2647      0.437     -0.606      0.545      -1.121       0.592
# Housing_A152                                           -0.4280      0.277     -1.543      0.123      -0.972       0.116
# Housing_A153                                           -0.2358      0.559     -0.422      0.673      -1.332       0.860
# Other_installment_plans_A142                           -0.0958      0.535     -0.179      0.858      -1.144       0.952
# Other_installment_plans_A143                           -0.4709      0.286     -1.647      0.100      -1.031       0.090
# Duration_in_month                                       0.0220      0.011      2.041      0.041       0.001       0.043
# Credit_amount                                        9.537e-05    4.7e-05      2.031      0.042    3.33e-06       0.000
# Age_in_years                                           -0.0317      0.011     -2.815      0.005      -0.054      -0.010
# Number_of_existing_credits_at_this_bank                 0.2834      0.219      1.293      0.196      -0.146       0.713
# Installment_rate_in_percentage_of_disposable_income     0.3054      0.101      3.014      0.003       0.107       0.504
# Present_residence_since                                 0.0304      0.101      0.300      0.764      -0.168       0.229
# =======================================================================================================================

# %%
# 로지스틱 결과 p-value값에 의해서 가장 무의미한 변수들을 먼저 제거해야 한다.

# %%
# VIF를 계산
cnames = x_train.drop(remove_cols, axis = 1).columns
for i in range(0, len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train.drop(remove_cols, axis = 1)[yvar], sm.add_constant(x_train.drop(remove_cols, axis = 1)[xvars]))
    res = mod.fit()
    vif = 1 /(1 - res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# Status_of_existing_checking_account_A12 1.693
# Status_of_existing_checking_account_A13 1.237
# Status_of_existing_checking_account_A14 1.808
# Credit_history_A31 2.19
# Credit_history_A32 6.923
# Credit_history_A33 2.894
# Credit_history_A34 5.994
# Savings_account/bonds_A62 1.146
# Savings_account/bonds_A63 1.098
# Savings_account/bonds_A64 1.09
# Savings_account/bonds_A65 1.179
# Purpose_A41 1.401
# Purpose_A410 1.17
# Purpose_A42 1.537
# Purpose_A43 1.709
# Purpose_A44 1.078
# Purpose_A45 1.114
# Purpose_A46 1.189
# Purpose_A48 1.079
# Purpose_A49 1.46
# Property_A122 1.542
# Property_A123 1.634
# Property_A124 3.396
# Present_employment_since_A72 3.257
# Present_employment_since_A73 4.341
# Present_employment_since_A74 3.321
# Present_employment_since_A75 3.922
# Housing_A152 1.743
# Housing_A153 3.385
# Other_installment_plans_A142 1.312
# Other_installment_plans_A143 1.388
# Duration_in_month 2.007
# Credit_amount 2.411
# Age_in_years 1.462
# Number_of_existing_credits_at_this_bank 1.55
# Installment_rate_in_percentage_of_disposable_income 1.301
# Present_residence_since 1.329

# %% [markdown]
# ## C 통계량을 계산

# %%
# 학습모델을 이용해서 y_pred 예측
y_pred = logistic_model.predict(sm.add_constant(x_train.drop(remove_cols, axis = 1))).to_frame()
y_pred.columns = ['probs']
both = pd.concat([y_train, y_pred], axis = 1)

# %%
# 데이터 프레임 확인
both
# Out:
#      class     probs
# 541      0  0.219357
# 440      0  0.236999
# 482      0  0.275018
# 422      0  0.093608
# 778      0  0.025235
# ..     ...       ...
# 106      1  0.609497
# 270      0  0.165358
# 860      0  0.024006
# 435      1  0.108405
# 102      0  0.043791
#
# [700 rows x 2 columns]

# %%
# class가 1인 테이블과 class가 0인 테이블을 분리하자.
zeros = both[both['class'] == 0]
ones = both[both['class'] == 1]

# %%
# 두 테이블을 카티션 곱을 하자
def df_crossjoin(df1, df2):
    df1['_tmpkey'] = 1
    df2['_tmpkey'] = 1
    res = pd.merge(df1,df2, on = '_tmpkey').drop(['_tmpkey'], axis = 1)
    res.index = pd.MultiIndex.from_product((df1.index, df2.index))
    df1.drop('_tmpkey', axis = 1, inplace = True)
    df2.drop('_tmpkey', axis = 1, inplace = True)
    return res

# %%
# 카티션 곱
joined_data = df_crossjoin(ones, zeros)
joined_data
# Out:
# <ipython-input-38-dcddc8a1ac4c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['_tmpkey'] = 1
# <ipython-input-38-dcddc8a1ac4c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['_tmpkey'] = 1
# C:\Users\bcduc\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          class_x   probs_x  class_y   probs_y
# 949 541        1  0.105378        0  0.219357
#     440        1  0.105378        0  0.236999
#     482        1  0.105378        0  0.275018
#     422        1  0.105378        0  0.093608
#     778        1  0.105378        0  0.025235
# ...          ...       ...      ...       ...
# 435 20         1  0.108405        0  0.149160
#     71         1  0.108405        0  0.024865
#     270        1  0.108405        0  0.165358
#     860        1  0.108405        0  0.024006
#     102        1  0.108405        0  0.043791
#
# [102619 rows x 4 columns]

# %%
# C 통계값 계산하기
joined_data['concordant_pair'] = 0
joined_data.loc[joined_data['probs_x'] > joined_data['probs_y'], 'concordant_pair'] = 1

joined_data['discordant_pair'] = 0
joined_data.loc[joined_data['probs_x'] < joined_data['probs_y'], 'discordant_pair'] = 1

joined_data['tied_pair'] = 0
joined_data.loc[joined_data['probs_x'] == joined_data['probs_y'], 'tied_pair'] = 1

# %%
# 데이터 확인하기
joined_data
# Out:
#          class_x   probs_x  class_y   probs_y  concordant_pair  \
# 949 541        1  0.105378        0  0.219357                0
#     440        1  0.105378        0  0.236999                0
#     482        1  0.105378        0  0.275018                0
#     422        1  0.105378        0  0.093608                1
#     778        1  0.105378        0  0.025235                1
# ...          ...       ...      ...       ...              ...
# 435 20         1  0.108405        0  0.149160                0
#     71         1  0.108405        0  0.024865                1
#     270        1  0.108405        0  0.165358                0
#     860        1  0.108405        0  0.024006                1
#     102        1  0.108405        0  0.043791                1
#
#          discordant_pair  tied_pair
# 949 541                1          0
#     440                1          0
#     482                1          0
#     422                0          0
#     778                0          0
# ...                  ...        ...
# 435 20                 1          0
#     71                 0          0
#     270                1          0
#     860                0          0
#     102                0          0
#
# [102619 rows x 7 columns]

# %%
# C 통계량 계산하기
p_conc = joined_data['concordant_pair'].sum()/joined_data.shape[0]
p_disc = joined_data['discordant_pair'].sum()/joined_data.shape[0]
c_statistic = 0.5 + (p_conc - p_disc)/2
print(round(c_statistic, 4))
# Out:
# 0.8185

# %% [markdown]
# # 통합

# %%
# 제거할 컬럼 정의
remove_cols_extra_dummy = [
    'Status_of_existing_checking_account_A11',
    'Credit_history_A30',
    'Savings_account/bonds_A61',
    'Purpose_A40',
    'Property_A121',
    'Present_employment_since_A71',
    'Housing_A151',
    'Other_installment_plans_A141',
    
]
# 실행이 반복될 때마다 가장 무의미한 변수와 다중공선성을 갖는 변수를
# remove_cols_insig 리스트에 추가한다.
remove_cols_insig = list()
remove_cols = list(set(remove_cols_extra_dummy + remove_cols_insig))

# %%
# 실행이 반복될 때마다 가장 무의미한 변수와 다중공선성을 갖는 변수를
# remove_cols_insig 리스트에 추가한다.
p_max = logistic_model.pvalues[1:].max()

while p_max >= 0.05:
    logistic_model = sm.Logit(y_train, sm.add_constant(x_train.drop(remove_cols, axis = 1))).fit()
    col_names = list(logistic_model.params.index[1:])
    p_max = logistic_model.pvalues[1:].max()
    for col in col_names:
        if logistic_model.pvalues[col] == p_max:

            remove_cols_insig.append(col)
            remove_cols = list(set(remove_cols_extra_dummy + remove_cols_insig))
            col_names.pop((col_names.index(col)))



            logistic_model = sm.Logit(y_train, sm.add_constant(x_train.drop(remove_cols, axis = 1))).fit()
            p_max = logistic_model.pvalues.max()

    # 학습모델을 이용해서 y_pred 예측
    y_pred = logistic_model.predict(sm.add_constant(x_train.drop(remove_cols, axis = 1))).to_frame()
    y_pred.columns = ['probs']
    both = pd.concat([y_train, y_pred], axis = 1)

    # class가 1인 테이블과 class가 0인 테이블을 분리하자.
    zeros = both[both['class'] == 0]
    ones = both[both['class'] == 1]

    # 두 테이블을 카티션 곱을 하자
    def df_crossjoin(df1, df2):
        df1['_tmpkey'] = 1
        df2['_tmpkey'] = 1
        res = pd.merge(df1,df2, on = '_tmpkey').drop(['_tmpkey'], axis = 1)
        res.index = pd.MultiIndex.from_product((df1.index, df2.index))
        df1.drop('_tmpkey', axis = 1, inplace = True)
        df2.drop('_tmpkey', axis = 1, inplace = True)
        return res

    # 카티션 곱
    joined_data = df_crossjoin(ones, zeros)

    # C 통계값 계산하기
    joined_data['concordant_pair'] = 0
    joined_data.loc[joined_data['probs_x'] > joined_data['probs_y'], 'concordant_pair'] = 1

    joined_data['discordant_pair'] = 0
    joined_data.loc[joined_data['probs_x'] < joined_data['probs_y'], 'discordant_pair'] = 1

    joined_data['tied_pair'] = 0
    joined_data.loc[joined_data['probs_x'] == joined_data['probs_y'], 'tied_pair'] = 1

    # C 통계량 계산하기
    p_conc = joined_data['concordant_pair'].sum()/joined_data.shape[0]
    p_disc = joined_data['discordant_pair'].sum()/joined_data.shape[0]
    c_statistic = 0.5 + (p_conc - p_disc)/2

    # VIF를 계산
    cnames = x_train.drop(remove_cols, axis = 1).columns
    for i in range(0, len(cnames)):
        xvars = list(cnames)
        yvar = xvars.pop(i)
        mod = sm.OLS(x_train.drop(remove_cols, axis = 1)[yvar], sm.add_constant(x_train.drop(remove_cols, axis = 1)[xvars]))
        res = mod.fit()
        vif = 1 /(1 - res.rsquared)
        print(yvar, round(vif, 3))

    print(logistic_model.aic, round(c_statistic, 4))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.462575
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462582
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462591
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462610
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462674
#          Iterations 7
# Status_of_existing_checking_account_A12 1.686
# Status_of_existing_checking_account_A13 1.23
# Status_of_existing_checking_account_A14 1.803
# <ipython-input-44-07e4438a5128>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['_tmpkey'] = 1
# <ipython-input-44-07e4438a5128>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['_tmpkey'] = 1
# C:\Users\bcduc\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Credit_history_A32 3.717
# Credit_history_A33 1.957
# Credit_history_A34 3.632
# Savings_account/bonds_A62 1.14
# Savings_account/bonds_A63 1.096
# Savings_account/bonds_A64 1.083
# Savings_account/bonds_A65 1.171
# Purpose_A41 1.39
# Purpose_A410 1.162
# Purpose_A42 1.526
# Purpose_A43 1.697
# Purpose_A44 1.077
# Purpose_A45 1.109
# Purpose_A46 1.181
# Purpose_A48 1.077
# Purpose_A49 1.438
# Property_A122 1.531
# Property_A123 1.623
# Property_A124 3.357
# Present_employment_since_A72 1.253
# Present_employment_since_A74 1.245
# Present_employment_since_A75 1.426
# Housing_A152 1.624
# Housing_A153 3.383
# Other_installment_plans_A143 1.137
# Duration_in_month 1.989
# Credit_amount 2.374
# Age_in_years 1.373
# Number_of_existing_credits_at_this_bank 1.494
# Installment_rate_in_percentage_of_disposable_income 1.289
# 715.743419690355 0.8181
# Optimization terminated successfully.
#          Current function value: 0.462674
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462764
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.462899
#          Iterations 7
# Status_of_existing_checking_account_A12 1.683
# Status_of_existing_checking_account_A13 1.227
# Status_of_existing_checking_account_A14 1.801
# Credit_history_A32 3.702
# Credit_history_A33 1.94
# Credit_history_A34 3.625
# Savings_account/bonds_A62 1.137
# Savings_account/bonds_A63 1.092
# Savings_account/bonds_A64 1.079
# Savings_account/bonds_A65 1.161
# Purpose_A41 1.319
# Purpose_A410 1.152
# Purpose_A42 1.434
# Purpose_A43 1.578
# Purpose_A44 1.068
# Purpose_A45 1.095
# Purpose_A48 1.071
# Purpose_A49 1.389
# Property_A122 1.526
# Property_A123 1.617
# Property_A124 1.955
# Present_employment_since_A72 1.245
# Present_employment_since_A74 1.239
# Present_employment_since_A75 1.422
# Housing_A152 1.425
# Other_installment_plans_A143 1.132
# Duration_in_month 1.976
# Credit_amount 2.369
# Age_in_years 1.319
# Number_of_existing_credits_at_this_bank 1.492
# Installment_rate_in_percentage_of_disposable_income 1.284
# 712.058301788045 0.8182
# Optimization terminated successfully.
#          Current function value: 0.462899
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.463124
#          Iterations 7
# Status_of_existing_checking_account_A12 1.682
# Status_of_existing_checking_account_A13 1.227
# Status_of_existing_checking_account_A14 1.801
# Credit_history_A32 3.7
# Credit_history_A33 1.94
# Credit_history_A34 3.625
# Savings_account/bonds_A62 1.136
# Savings_account/bonds_A63 1.088
# Savings_account/bonds_A64 1.079
# Savings_account/bonds_A65 1.159
# Purpose_A41 1.318
# Purpose_A410 1.147
# Purpose_A42 1.433
# Purpose_A43 1.578
# Purpose_A44 1.067
# Purpose_A45 1.095
# Purpose_A48 1.071
# Purpose_A49 1.389
# Property_A122 1.523
# Property_A123 1.617
# Property_A124 1.955
# Present_employment_since_A74 1.129
# Present_employment_since_A75 1.331
# Housing_A152 1.421
# Other_installment_plans_A143 1.131
# Duration_in_month 1.974
# Credit_amount 2.369
# Age_in_years 1.298
# Number_of_existing_credits_at_this_bank 1.492
# Installment_rate_in_percentage_of_disposable_income 1.284
# 710.3741798449012 0.8182
# Optimization terminated successfully.
#          Current function value: 0.463124
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.463358
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.463876
#          Iterations 7
# Status_of_existing_checking_account_A12 1.681
# Status_of_existing_checking_account_A13 1.227
# Status_of_existing_checking_account_A14 1.798
# Credit_history_A32 3.699
# Credit_history_A33 1.933
# Credit_history_A34 3.617
# Savings_account/bonds_A62 1.133
# Savings_account/bonds_A63 1.085
# Savings_account/bonds_A64 1.076
# Savings_account/bonds_A65 1.15
# Purpose_A41 1.303
# Purpose_A410 1.146
# Purpose_A42 1.408
# Purpose_A43 1.526
# Purpose_A45 1.09
# Purpose_A48 1.067
# Purpose_A49 1.376
# Property_A122 1.521
# Property_A123 1.605
# Property_A124 1.938
# Present_employment_since_A74 1.052
# Housing_A152 1.416
# Other_installment_plans_A143 1.13
# Duration_in_month 1.97
# Credit_amount 2.359
# Age_in_years 1.185
# Number_of_existing_credits_at_this_bank 1.488
# Installment_rate_in_percentage_of_disposable_income 1.267
# 707.4260095354381 0.817
# Optimization terminated successfully.
#          Current function value: 0.463876
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.464466
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.465211
#          Iterations 7
# Status_of_existing_checking_account_A12 1.618
# Status_of_existing_checking_account_A13 1.22
# Status_of_existing_checking_account_A14 1.758
# Credit_history_A32 3.695
# Credit_history_A33 1.932
# Credit_history_A34 3.598
# Savings_account/bonds_A63 1.065
# Savings_account/bonds_A64 1.063
# Savings_account/bonds_A65 1.106
# Purpose_A41 1.283
# Purpose_A410 1.14
# Purpose_A42 1.374
# Purpose_A43 1.464
# Purpose_A48 1.062
# Purpose_A49 1.348
# Property_A122 1.507
# Property_A123 1.6
# Property_A124 1.936
# Present_employment_since_A74 1.047
# Housing_A152 1.404
# Other_installment_plans_A143 1.121
# Duration_in_month 1.964
# Credit_amount 2.352
# Age_in_years 1.185
# Number_of_existing_credits_at_this_bank 1.486
# Installment_rate_in_percentage_of_disposable_income 1.26
# 705.2956682912817 0.8148
# Optimization terminated successfully.
#          Current function value: 0.465211
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.466273
#          Iterations 7
# Status_of_existing_checking_account_A12 1.616
# Status_of_existing_checking_account_A13 1.219
# Status_of_existing_checking_account_A14 1.758
# Credit_history_A32 3.59
# Credit_history_A33 1.914
# Credit_history_A34 3.458
# Savings_account/bonds_A63 1.059
# Savings_account/bonds_A64 1.063
# Savings_account/bonds_A65 1.104
# Purpose_A41 1.282
# Purpose_A410 1.14
# Purpose_A42 1.371
# Purpose_A43 1.464
# Purpose_A48 1.062
# Purpose_A49 1.343
# Property_A122 1.507
# Property_A123 1.599
# Property_A124 1.933
# Present_employment_since_A74 1.046
# Housing_A152 1.402
# Other_installment_plans_A143 1.115
# Duration_in_month 1.956
# Credit_amount 2.351
# Age_in_years 1.18
# Installment_rate_in_percentage_of_disposable_income 1.26
# 704.7819071938146 0.8147
# Optimization terminated successfully.
#          Current function value: 0.466273
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.467310
#          Iterations 7
# Status_of_existing_checking_account_A12 1.599
# Status_of_existing_checking_account_A13 1.218
# Status_of_existing_checking_account_A14 1.743
# Credit_history_A32 3.498
# Credit_history_A33 1.913
# Credit_history_A34 3.387
# Savings_account/bonds_A63 1.058
# Savings_account/bonds_A64 1.062
# Savings_account/bonds_A65 1.101
# Purpose_A41 1.217
# Purpose_A410 1.118
# Purpose_A42 1.263
# Purpose_A43 1.304
# Purpose_A48 1.055
# Property_A122 1.506
# Property_A123 1.596
# Property_A124 1.906
# Present_employment_since_A74 1.043
# Housing_A152 1.402
# Other_installment_plans_A143 1.104
# Duration_in_month 1.916
# Credit_amount 2.35
# Age_in_years 1.179
# Installment_rate_in_percentage_of_disposable_income 1.26
# 704.234367720262 0.8139
# Optimization terminated successfully.
#          Current function value: 0.467310
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.468392
#          Iterations 7
# Status_of_existing_checking_account_A12 1.598
# Status_of_existing_checking_account_A13 1.218
# Status_of_existing_checking_account_A14 1.741
# Credit_history_A32 3.497
# Credit_history_A33 1.912
# Credit_history_A34 3.386
# Savings_account/bonds_A63 1.058
# Savings_account/bonds_A64 1.061
# Savings_account/bonds_A65 1.099
# Purpose_A41 1.202
# Purpose_A42 1.254
# Purpose_A43 1.297
# Purpose_A48 1.055
# Property_A122 1.506
# Property_A123 1.596
# Property_A124 1.906
# Present_employment_since_A74 1.037
# Housing_A152 1.399
# Other_installment_plans_A143 1.091
# Duration_in_month 1.909
# Credit_amount 2.25
# Age_in_years 1.179
# Installment_rate_in_percentage_of_disposable_income 1.257
# 703.7487369367541 0.8129
# Optimization terminated successfully.
#          Current function value: 0.468392
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.469661
#          Iterations 7
# Status_of_existing_checking_account_A12 1.598
# Status_of_existing_checking_account_A13 1.215
# Status_of_existing_checking_account_A14 1.728
# Credit_history_A33 1.116
# Credit_history_A34 1.164
# Savings_account/bonds_A63 1.058
# Savings_account/bonds_A64 1.061
# Savings_account/bonds_A65 1.097
# Purpose_A41 1.199
# Purpose_A42 1.253
# Purpose_A43 1.287
# Purpose_A48 1.051
# Property_A122 1.506
# Property_A123 1.593
# Property_A124 1.903
# Present_employment_since_A74 1.037
# Housing_A152 1.397
# Other_installment_plans_A143 1.038
# Duration_in_month 1.9
# Credit_amount 2.25
# Age_in_years 1.175
# Installment_rate_in_percentage_of_disposable_income 1.257
# 703.5258243638268 0.8124
# Optimization terminated successfully.
#          Current function value: 0.469661
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.471256
#          Iterations 7
# Status_of_existing_checking_account_A12 1.597
# Status_of_existing_checking_account_A13 1.215
# Status_of_existing_checking_account_A14 1.727
# Credit_history_A33 1.113
# Credit_history_A34 1.156
# Savings_account/bonds_A63 1.057
# Savings_account/bonds_A64 1.061
# Savings_account/bonds_A65 1.092
# Purpose_A41 1.196
# Purpose_A42 1.242
# Purpose_A43 1.27
# Property_A122 1.497
# Property_A123 1.591
# Property_A124 1.903
# Present_employment_since_A74 1.036
# Housing_A152 1.397
# Other_installment_plans_A143 1.038
# Duration_in_month 1.897
# Credit_amount 2.247
# Age_in_years 1.175
# Installment_rate_in_percentage_of_disposable_income 1.253
# 703.7582966174871 0.8106
# Optimization terminated successfully.
#          Current function value: 0.471256
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.472573
#          Iterations 7
# Status_of_existing_checking_account_A12 1.592
# Status_of_existing_checking_account_A13 1.214
# Status_of_existing_checking_account_A14 1.724
# Credit_history_A33 1.113
# Credit_history_A34 1.156
# Savings_account/bonds_A63 1.056
# Savings_account/bonds_A64 1.056
# Savings_account/bonds_A65 1.091
# Purpose_A41 1.196
# Purpose_A42 1.216
# Purpose_A43 1.264
# Property_A123 1.196
# Property_A124 1.676
# Present_employment_since_A74 1.036
# Housing_A152 1.396
# Other_installment_plans_A143 1.038
# Duration_in_month 1.897
# Credit_amount 2.232
# Age_in_years 1.174
# Installment_rate_in_percentage_of_disposable_income 1.249
# 703.6024918641734 0.8093
# Optimization terminated successfully.
#          Current function value: 0.472573
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.473157
#          Iterations 7
# Status_of_existing_checking_account_A12 1.59
# Status_of_existing_checking_account_A13 1.212
# Status_of_existing_checking_account_A14 1.715
# Credit_history_A33 1.111
# Credit_history_A34 1.154
# Savings_account/bonds_A63 1.054
# Savings_account/bonds_A64 1.053
# Savings_account/bonds_A65 1.086
# Purpose_A41 1.186
# Purpose_A42 1.209
# Purpose_A43 1.264
# Property_A124 1.526
# Present_employment_since_A74 1.036
# Housing_A152 1.395
# Other_installment_plans_A143 1.038
# Duration_in_month 1.887
# Credit_amount 2.216
# Age_in_years 1.166
# Installment_rate_in_percentage_of_disposable_income 1.244
# 702.4200543632002 0.8085
# Optimization terminated successfully.
#          Current function value: 0.473157
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.474422
#          Iterations 7
# Status_of_existing_checking_account_A12 1.588
# Status_of_existing_checking_account_A13 1.208
# Status_of_existing_checking_account_A14 1.715
# Credit_history_A33 1.104
# Credit_history_A34 1.154
# Savings_account/bonds_A63 1.054
# Savings_account/bonds_A64 1.052
# Savings_account/bonds_A65 1.085
# Purpose_A41 1.186
# Purpose_A42 1.196
# Purpose_A43 1.254
# Present_employment_since_A74 1.035
# Housing_A152 1.068
# Other_installment_plans_A143 1.028
# Duration_in_month 1.88
# Credit_amount 2.188
# Age_in_years 1.113
# Installment_rate_in_percentage_of_disposable_income 1.237
# 702.1914122662104 0.8068
# Optimization terminated successfully.
#          Current function value: 0.474422
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.475764
#          Iterations 7
# Status_of_existing_checking_account_A12 1.586
# Status_of_existing_checking_account_A13 1.207
# Status_of_existing_checking_account_A14 1.683
# Credit_history_A33 1.104
# Credit_history_A34 1.154
# Savings_account/bonds_A64 1.041
# Savings_account/bonds_A65 1.061
# Purpose_A41 1.186
# Purpose_A42 1.196
# Purpose_A43 1.254
# Present_employment_since_A74 1.034
# Housing_A152 1.068
# Other_installment_plans_A143 1.027
# Duration_in_month 1.878
# Credit_amount 2.181
# Age_in_years 1.112
# Installment_rate_in_percentage_of_disposable_income 1.236
# 702.0698751579764 0.8066
# Optimization terminated successfully.
#          Current function value: 0.475764
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.477777
#          Iterations 6
# Status_of_existing_checking_account_A12 1.577
# Status_of_existing_checking_account_A13 1.204
# Status_of_existing_checking_account_A14 1.663
# Credit_history_A33 1.104
# Credit_history_A34 1.15
# Savings_account/bonds_A65 1.045
# Purpose_A41 1.185
# Purpose_A42 1.194
# Purpose_A43 1.253
# Present_employment_since_A74 1.034
# Housing_A152 1.068
# Other_installment_plans_A143 1.027
# Duration_in_month 1.877
# Credit_amount 2.177
# Age_in_years 1.11
# Installment_rate_in_percentage_of_disposable_income 1.235
# 702.8876963511178 0.8042
# Optimization terminated successfully.
#          Current function value: 0.477777
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479670
#          Iterations 6
# Status_of_existing_checking_account_A12 1.575
# Status_of_existing_checking_account_A13 1.203
# Status_of_existing_checking_account_A14 1.662
# Credit_history_A33 1.101
# Credit_history_A34 1.147
# Savings_account/bonds_A65 1.045
# Purpose_A41 1.184
# Purpose_A42 1.189
# Purpose_A43 1.253
# Housing_A152 1.068
# Other_installment_plans_A143 1.027
# Duration_in_month 1.869
# Credit_amount 2.177
# Age_in_years 1.092
# Installment_rate_in_percentage_of_disposable_income 1.235
# 703.5380081165571 0.8022
# Optimization terminated successfully.
#          Current function value: 0.479670
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481748
#          Iterations 6
# Status_of_existing_checking_account_A13 1.084
# Status_of_existing_checking_account_A14 1.145
# Credit_history_A33 1.091
# Credit_history_A34 1.147
# Savings_account/bonds_A65 1.043
# Purpose_A41 1.182
# Purpose_A42 1.187
# Purpose_A43 1.241
# Housing_A152 1.065
# Other_installment_plans_A143 1.027
# Duration_in_month 1.868
# Credit_amount 2.16
# Age_in_years 1.091
# Installment_rate_in_percentage_of_disposable_income 1.228
# 704.4471888075724 0.8006
# Optimization terminated successfully.
#          Current function value: 0.481748
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484563
#          Iterations 6
# Status_of_existing_checking_account_A14 1.088
# Credit_history_A33 1.091
# Credit_history_A34 1.145
# Savings_account/bonds_A65 1.042
# Purpose_A41 1.182
# Purpose_A42 1.186
# Purpose_A43 1.234
# Housing_A152 1.065
# Other_installment_plans_A143 1.023
# Duration_in_month 1.868
# Credit_amount 2.14
# Age_in_years 1.086
# Installment_rate_in_percentage_of_disposable_income 1.225
# 706.3887665827774 0.7978
# Optimization terminated successfully.
#          Current function value: 0.484563
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487302
#          Iterations 6
# Status_of_existing_checking_account_A14 1.076
# Credit_history_A34 1.092
# Savings_account/bonds_A65 1.042
# Purpose_A41 1.181
# Purpose_A42 1.183
# Purpose_A43 1.229
# Housing_A152 1.063
# Other_installment_plans_A143 1.022
# Duration_in_month 1.861
# Credit_amount 2.133
# Age_in_years 1.086
# Installment_rate_in_percentage_of_disposable_income 1.225
# 708.2233793927135 0.7955
# Optimization terminated successfully.
#          Current function value: 0.487302
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489892
#          Iterations 6
# Status_of_existing_checking_account_A14 1.075
# Credit_history_A34 1.089
# Savings_account/bonds_A65 1.041
# Purpose_A41 1.179
# Purpose_A42 1.181
# Purpose_A43 1.229
# Housing_A152 1.062
# Duration_in_month 1.853
# Credit_amount 2.132
# Age_in_years 1.084
# Installment_rate_in_percentage_of_disposable_income 1.223
# 709.8486431323082 0.7945
# Optimization terminated successfully.
#          Current function value: 0.489892
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492941
#          Iterations 6
# Status_of_existing_checking_account_A14 1.074
# Credit_history_A34 1.085
# Savings_account/bonds_A65 1.041
# Purpose_A41 1.179
# Purpose_A42 1.18
# Purpose_A43 1.227
# Housing_A152 1.062
# Credit_amount 1.194
# Age_in_years 1.078
# Installment_rate_in_percentage_of_disposable_income 1.115
# 712.1178999833721 0.7906
# Optimization terminated successfully.
#          Current function value: 0.492941
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496134
#          Iterations 6
# Status_of_existing_checking_account_A14 1.067
# Credit_history_A34 1.085
# Purpose_A41 1.171
# Purpose_A42 1.179
# Purpose_A43 1.225
# Housing_A152 1.062
# Credit_amount 1.181
# Age_in_years 1.075
# Installment_rate_in_percentage_of_disposable_income 1.113
# 714.58802772304 0.7863
# Optimization terminated successfully.
#          Current function value: 0.496134
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500850
#          Iterations 6
# Status_of_existing_checking_account_A14 1.066
# Credit_history_A34 1.084
# Purpose_A41 1.115
# Purpose_A43 1.091
# Housing_A152 1.058
# Credit_amount 1.178
# Age_in_years 1.054
# Installment_rate_in_percentage_of_disposable_income 1.112
# 719.1903933154803 0.7801
# Optimization terminated successfully.
#          Current function value: 0.500850
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.506256
#          Iterations 6
# Status_of_existing_checking_account_A14 1.056
# Credit_history_A34 1.073
# Purpose_A41 1.107
# Purpose_A43 1.083
# Credit_amount 1.172
# Age_in_years 1.051
# Installment_rate_in_percentage_of_disposable_income 1.112
# 724.758912303125 0.7746
# Optimization terminated successfully.
#          Current function value: 0.506256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511914
#          Iterations 6
# Status_of_existing_checking_account_A14 1.053
# Credit_history_A34 1.036
# Purpose_A41 1.104
# Purpose_A43 1.082
# Credit_amount 1.17
# Installment_rate_in_percentage_of_disposable_income 1.11
# 730.6797051084077 0.7656

# %%
logistic_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  class   No. Observations:                  700
# Model:                          Logit   Df Residuals:                      693
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 04 Sep 2020   Pseudo R-squ.:                  0.1603
# Time:                        22:10:18   Log-Likelihood:                -358.34
# converged:                       True   LL-Null:                       -426.75
# Covariance Type:            nonrobust   LLR p-value:                 4.677e-27
# =======================================================================================================================
#                                                           coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# const                                                  -1.4003      0.344     -4.072      0.000      -2.074      -0.726
# Status_of_existing_checking_account_A14                -1.4608      0.217     -6.741      0.000      -1.886      -1.036
# Credit_history_A34                                     -1.0136      0.229     -4.425      0.000      -1.463      -0.565
# Purpose_A41                                            -1.1083      0.358     -3.094      0.002      -1.811      -0.406
# Purpose_A43                                            -0.7534      0.219     -3.443      0.001      -1.182      -0.325
# Credit_amount                                           0.0002   3.34e-05      4.698      0.000    9.14e-05       0.000
# Installment_rate_in_percentage_of_disposable_income     0.3303      0.090      3.666      0.000       0.154       0.507
# =======================================================================================================================
# """

# %%
remove_cols
# Out:
# ['Purpose_A45',
#  'Property_A121',
#  'Other_installment_plans_A141',
#  'Property_A123',
#  'Credit_history_A31',
#  'Savings_account/bonds_A63',
#  'Status_of_existing_checking_account_A11',
#  'Purpose_A410',
#  'Savings_account/bonds_A64',
#  'Purpose_A40',
#  'Status_of_existing_checking_account_A13',
#  'Other_installment_plans_A143',
#  'Purpose_A46',
#  'Present_employment_since_A72',
#  'Savings_account/bonds_A65',
#  'Property_A122',
#  'Credit_history_A30',
#  'Savings_account/bonds_A62',
#  'Duration_in_month',
#  'Present_employment_since_A74',
#  'Present_residence_since',
#  'Present_employment_since_A71',
#  'Housing_A151',
#  'Property_A124',
#  'Age_in_years',
#  'Purpose_A44',
#  'Savings_account/bonds_A61',
#  'Credit_history_A33',
#  'Housing_A152',
#  'Purpose_A42',
#  'Present_employment_since_A75',
#  'Housing_A153',
#  'Credit_history_A32',
#  'Purpose_A48',
#  'Number_of_existing_credits_at_this_bank',
#  'Purpose_A49',
#  'Status_of_existing_checking_account_A12',
#  'Present_employment_since_A73',
#  'Other_installment_plans_A142']

# %% [markdown]
# ## TPR과 FPR에 관한 ROC 곡선을 그린다

# %%
# 그래프를 그리기 위한 모듈 가져오기
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import auc

# %%
# fpr, tpr, thresholds값을 구한다.
fpr, tpr, thresholds = metrics.roc_curve(both['class'],both['probs'],pos_label = 1)

# %%
# 데이터 shape 확인
fpr.shape, tpr.shape, thresholds.shape
# Out:
# ((254,), (254,), (254,))

# %%
# auc 커브를 그리자
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color = 'darkorange', lw = lw, label = 'ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0,1], [0,1], color = 'navy', lw = lw, linestyle = '--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate ( 1 - Specificity)')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - German Credit Data')
plt.legend(loc = 'lower right')
plt.show()

# %%
# 그리드 검색 => 최적의 임계값 커트라인을 결정
for i in list(np.arange(0.0, 1.0, 0.1)):
    both['y_pred'] = 0
    both.loc[both['probs'] > i, 'y_pred'] = 1
    print("Threshold", i, "Train Accuracy:", round(accuracy_score(both['class'], both['y_pred']),4))
# Out:
# Threshold 0.0 Train Accuracy: 0.2986
# Threshold 0.1 Train Accuracy: 0.4786
# Threshold 0.2 Train Accuracy: 0.6157
# Threshold 0.30000000000000004 Train Accuracy: 0.6771
# Threshold 0.4 Train Accuracy: 0.7286
# Threshold 0.5 Train Accuracy: 0.74
# Threshold 0.6000000000000001 Train Accuracy: 0.7171
# Threshold 0.7000000000000001 Train Accuracy: 0.7143
# Threshold 0.8 Train Accuracy: 0.7057
# Threshold 0.9 Train Accuracy: 0.7014

# %%
# Threshold값 0.5에서 0.74를 기록
# 따라서, 훈련데이터를 분류하기 위한 임계값 0.5로 설정
both['y_pred'] = 0
both.loc[both['probs'] > 0.5 , 'y_pred'] = 1

# %%
pd.crosstab(both['class'], both['y_pred'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted    0   1
# Actual
# 0          430  61
# 1          121  88

# %%
accuracy_score(both['class'], both['y_pred'])
# Out:
# 0.74

# %% [markdown]
# ## Test 데이터에 적용

# %%
# 학습된 모델로 테스트 데이터에 적용
y_pred_test = logistic_model.predict(sm.add_constant(x_test.drop(remove_cols, axis = 1))).to_frame()
y_pred_test.columns = ['probs']

# %%
# 데이터 프레임 만들기
both_test = pd.concat([y_test, y_pred_test], axis = 1)
both_test['y_pred'] = 0
both_test.loc[both_test['probs'] > 0.5, 'y_pred'] = 1

# %%
# confusion matrix 작성
pd.crosstab(both_test['class'], both_test['y_pred'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted    0   1
# Actual
# 0          185  24
# 1           58  33

# %%
# 정확도 확인
round(accuracy_score(both_test['class'], both_test['y_pred']),4)
# Out:
# 0.7267
